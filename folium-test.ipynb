# %%
#!pip install folium
#!pip install Leaflet

# %%
import folium

# %%
m = folium.Map(location=[45.5236, -122.6750]);m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('Portland.html')

# %%
folium.Map(
    location=[45.5236, -122.6750],
    tiles='Stamen Toner',
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Map(location=[6.980509,51.588057],
           tiles='Mapbox',
           API_key='pk.eyJ1IjoidG9iaWhlIiwiYSI6ImNqdXgwMXhjMTBpNGI0M3MxZGlrY3M3ZTkifQ._K5j2Z47FKFzintcnkT7iQ')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[45.372, -121.6972],
    zoom_start=12,
    tiles='Stamen Terrain'
)

tooltip = 'Click me!'

folium.Marker([45.3288, -121.6625], popup='<i>Mt. Hood Meadows</i>', tooltip=tooltip).add_to(m)
folium.Marker([45.3311, -121.7113], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[45.372, -121.6972],
    zoom_start=12,
    tiles='Stamen Terrain'
)

folium.Marker(
    location=[45.3288, -121.6625],
    popup=folium.Popup('Mt. Hood Meadows', show=True),
    icon=folium.Icon(icon='cloud')
).add_to(m)

folium.Marker(
    location=[45.3311, -121.7113],
    popup=folium.Popup('Timberline Lodge', show=True),
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[45.3300, -121.6823],
    popup=folium.Popup('Some Other Location', show=True),
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import os

# %%
m = folium.Map([45, 0], zoom_start=4)

folium.Marker([45, -30], popup='inline implicit popup').add_to(m)

folium.CircleMarker(
    location=[45, -10],
    radius=25,
    fill=True,
    popup=folium.Popup('inline explicit Popup')
).add_to(m)

ls = folium.PolyLine(
    locations=[[43, 7], [43, 13], [47, 13], [47, 7], [43, 7]],
    color='red'
)

ls.add_child(folium.Popup('outline Popup on Polyline'))
ls.add_to(m)

gj = folium.GeoJson(
    data={
        'type': 'Polygon',
        'coordinates': [[[27, 43], [33, 43], [33, 47], [27, 47]]]
    }
)

gj.add_child(folium.Popup('outline Popup on GeoJSON'))
gj.add_to(m)

m.save(os.path.join('C:\\Users\\he\\Documents\\results', 'simple_popups.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([45, 0], zoom_start=2)

folium.Marker(
    location=[45, -10],
    popup=folium.Popup("Let's try quotes", parse_html=True, max_width=100)
).add_to(m)

folium.Marker(
    location=[45, -30],
    popup=folium.Popup(u"Ça c'est chouette", parse_html=True, max_width='100%')
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

#You can find a full list here:
#https://fontawesome.com/icons?d=gallery
#use with: prefix='fa'

df = pd.DataFrame.from_dict(
    {'label1': ['foo', 'bar'],
     'label2': ['bob', 'rob'],
     'lat': [59.315875,59.415875],
     'lon': [18.054837,18.154837]
    }
)

m = folium.Map(
    location = [59.315875, 18.054837],
    tiles = 'CartoDB Positron',
    zoom_start = 9,
    attr = "http://cartodb.com/attributions"
    )
df.apply(lambda row: folium.Marker(
    location = [row['lat'],row['lon']],
    popup = folium.Popup(folium.Html("""
            <b>label1: </b> row['label'] </br>
            <b>label2: </b> row['label2']
            """, script=True), max_width=2650),
    icon = folium.Icon(color='red', 
                   icon='car',
                   icon_color='white',
                   prefix='fa'
                  )
    ).add_to(m), axis = 1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
from folium.features import DivIcon


text = 'Test'
circle_lat = 60
circle_lon = 10

m = folium.Map([60, 10], tiles='Mapbox Bright', zoom_start=5)
folium.Circle([circle_lat, circle_lon], 150000, fill=True).add_child(folium.Popup('My name is Circle')).add_to(m)
folium.map.Marker(
    [circle_lat + 0.5, circle_lon - 1.6],
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 24pt">%s</div>' % text,
        )
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.features import DivIcon

m = folium.Map(
    location=[45.3288, -121.6625],
    zoom_start=12,
    #tiles='Mapbox Bright'
)

p1 = [45.3288, -121.6625]
folium.Marker(p1, icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(7,20),
        html='<div style="font-size: 18pt; color : black">1</div>',
        )).add_to(m)
m.add_child(folium.CircleMarker(p1, radius=15))

p2 = [45.3311, -121.7113]
folium.Marker(p2, icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(7,20),
        html='<div style="font-size: 18pt; color : black">2</div>',
        )).add_to(m)
m.add_child(folium.CircleMarker(p2, radius=15))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data={
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "type": "Polygon",
        "coordinates": [
          [
            [
              6.102438569068909,
              50.76831897956019
            ],
            [
              6.103028655052185,
              50.76760649295936
            ],
            [
              6.104152500629425,
              50.7675403329387
            ],
            [
              6.104232966899872,
              50.76775068755199
            ],
            [
              6.104101538658142,
              50.7677930976417
            ],
            [
              6.104109585285187,
              50.76855986543264
            ],
            [
              6.102438569068909,
              50.76831897956019
            ]
          ]
        ]
      }
    }
  ]
}
m = folium.Map(
    location=[50.77,6.10],
    zoom_start=15,
    #tiles='Mapbox Bright'
)
folium.GeoJson(data,
    style_function=lambda x: {
        'color' : 'blue',
        'opacity': 0.6,
        'fillColor' : 'blue',
        }).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data['features']
# Out:
# [{'type': 'Feature',
#   'properties': {'style': {'color': 'blue',
#     'opacity': 0.6,
#     'fillColor': 'blue'},
#    'highlight': {}},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[6.102438569068909, 50.76831897956019],
#      [6.103028655052185, 50.76760649295936],
#      [6.104152500629425, 50.7675403329387],
#      [6.104232966899872, 50.76775068755199],
#      [6.104101538658142, 50.7677930976417],
#      [6.104109585285187, 50.76855986543264],
#      [6.102438569068909, 50.76831897956019]]]}}]

# %%
data['features'][0]['geometry']['coordinates'][0]
# Out:
# [[6.102438569068909, 50.76831897956019],
#  [6.103028655052185, 50.76760649295936],
#  [6.104152500629425, 50.7675403329387],
#  [6.104232966899872, 50.76775068755199],
#  [6.104101538658142, 50.7677930976417],
#  [6.104109585285187, 50.76855986543264],
#  [6.102438569068909, 50.76831897956019]]

# %%
data['features'][0]['geometry']['coordinates'][0][0]=[6.1025, 50.769]
m = folium.Map(
    location=[50.77,6.10],
    zoom_start=15,
    #tiles='Mapbox Bright'
)
folium.GeoJson(data,
    style_function=lambda x: {
        'color' : 'blue',
        'opacity': 0.6,
        'fillColor' : 'blue',
        }).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
